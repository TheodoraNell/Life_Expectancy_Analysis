# %%
# Initial imports
import pandas as pd
import hvplot.pandas
from pathlib import Path
import plotly.express as px
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %%
# Load the the dataset into the notebook

file_path = "C:/Users/theod/Bootcamp/FINAL_PROJECT/Module_20_Project/Data/CO2_emission 1990-2019.csv"

# %%
# create the dataframe without the numbered rows by using index_col=0
df = pd.read_csv(file_path,index_col=0)
df.head()
# Out:
#              country_code                     Region  \
# Country Name
# Aruba                 ABW  Latin America & Caribbean
# Afghanistan           AFG                 South Asia
# Angola                AGO         Sub-Saharan Africa
# Albania               ALB      Europe & Central Asia
# Andorra               AND      Europe & Central Asia
#
#                                       Indicator Name      1990      1991  \
# Country Name
# Aruba         CO2 emissions (metric tons per capita)       NaN       NaN
# Afghanistan   CO2 emissions (metric tons per capita)  0.191745  0.167682
# Angola        CO2 emissions (metric tons per capita)  0.553662  0.544539
# Albania       CO2 emissions (metric tons per capita)  1.819542  1.242810
# Andorra       CO2 emissions (metric tons per capita)  7.521832  7.235379
#
#                   1992      1993      1994      1995      1996  ...      2011  \
# Country Name                                                    ...
# ...

# %%
# examine how the data is shaped
# this is help to understand if we are dealing with a long or wide set

print(df.shape)
# Out:
# (215, 34)

# %%
# Check out the data types: this could reveal additonal conversions that might need to happen 

df.dtypes
# Out:
# country_code       object
# Region             object
# Indicator Name     object
# 1990              float64
# 1991              float64
# 1992              float64
# 1993              float64
# 1994              float64
# 1995              float64
# 1996              float64
# 1997              float64
# 1998              float64
# 1999              float64
# 2000              float64
# 2001              float64
# 2002              float64
# 2003              float64
# 2004              float64
# 2005              float64
# 2006              float64
# 2007              float64
# 2008              float64
# 2009              float64
# 2010              float64
# 2011              float64
# 2012              float64
# 2013              float64
# 2014              float64
# 2015              float64
# 2016              float64
# 2017              float64
# 2018              float64
# 2019              float64
# 2019.1            float64
# dtype: object

# %%
# Change index name
df.index.names = ['Country']

# %%
# Check on the data
print(df.shape)
df.head(5)
# Out:
# (215, 34)
#             country_code                     Region  \
# Country
# Aruba                ABW  Latin America & Caribbean
# Afghanistan          AFG                 South Asia
# Angola               AGO         Sub-Saharan Africa
# Albania              ALB      Europe & Central Asia
# Andorra              AND      Europe & Central Asia
#
#                                      Indicator Name      1990      1991  \
# Country
# Aruba        CO2 emissions (metric tons per capita)       NaN       NaN
# Afghanistan  CO2 emissions (metric tons per capita)  0.191745  0.167682
# Angola       CO2 emissions (metric tons per capita)  0.553662  0.544539
# Albania      CO2 emissions (metric tons per capita)  1.819542  1.242810
# Andorra      CO2 emissions (metric tons per capita)  7.521832  7.235379
#
#                  1992      1993      1994      1995      1996  ...      2011  \
# Country                                                        ...
# ...

# %%
# Remove rows that have at least 1 null value.

df.dropna(how='any', inplace=True)

# Check the dataset shape and head to make sure the nulls were removed

print(df.shape)

df.head()
# Out:
# (183, 34)
#                      country_code                      Region  \
# Country
# Afghanistan                   AFG                  South Asia
# Angola                        AGO          Sub-Saharan Africa
# Albania                       ALB       Europe & Central Asia
# Andorra                       AND       Europe & Central Asia
# United Arab Emirates          ARE  Middle East & North Africa
#
#                                               Indicator Name       1990  \
# Country
# Afghanistan           CO2 emissions (metric tons per capita)   0.191745
# Angola                CO2 emissions (metric tons per capita)   0.553662
# Albania               CO2 emissions (metric tons per capita)   1.819542
# Andorra               CO2 emissions (metric tons per capita)   7.521832
# United Arab Emirates  CO2 emissions (metric tons per capita)  30.195189
#
#                            1991       1992       1993       1994       1995  \
# Country
# ...

# %%
# Drop Columns 
df.drop(axis=1, labels=["country_code", "Region", "Indicator Name"], inplace=True)
df.head()
# Out:
#                            1990       1991       1992       1993       1994  \
# Country
# Afghanistan            0.191745   0.167682   0.095958   0.084721   0.075546
# Angola                 0.553662   0.544539   0.543557   0.708984   0.836804
# Albania                1.819542   1.242810   0.683700   0.638307   0.645355
# Andorra                7.521832   7.235379   6.963079   6.724178   6.541579
# United Arab Emirates  30.195189  31.778496  29.080926  29.275678  30.849333
#
#                            1995       1996       1997       1998       1999  \
# Country
# Afghanistan            0.068468   0.062588   0.056827   0.052691   0.040157
# Angola                 0.912141   1.072168   1.086637   1.091825   1.109860
# Albania                0.605436   0.612367   0.466921   0.572154   0.955359
# Andorra                6.733479   6.991595   7.307441   7.639539   7.923192
# United Arab Emirates  31.125018  30.928026  30.486333  29.663581  28.887108
#
# ...

# %%
df.drop([col for col in df.columns if '20' not in col],axis=1,inplace=True)

# %%
df.drop(['2016', '2017', '2018', '2019', '2019.1'], axis=1, inplace=True)
df.head()
# Out:
#                            2000       2001       2002       2003       2004  \
# Country
# Afghanistan            0.036574   0.033785   0.045574   0.051518   0.041655
# Angola                 0.988077   0.941829   0.895578   0.924869   0.930263
# Albania                1.026213   1.055496   1.232379   1.338985   1.404059
# Andorra                7.952286   7.721549   7.566240   7.242416   7.344262
# United Arab Emirates  27.035159  29.430270  28.501462  27.969270  27.038938
#
#                            2005       2006       2007       2008       2009  \
# Country
# Afghanistan            0.060419   0.066583   0.065312   0.128417   0.171862
# Angola                 0.813539   0.821840   0.811754   0.888658   0.939404
# Albania                1.338209   1.339996   1.393931   1.384311   1.441494
# Andorra                7.353780   6.790543   6.531047   6.439304   6.156687
# United Arab Emirates  25.382381  22.935104  21.370286  22.011469  19.832349
#
# ...

# %%
df = df.reset_index()
df = pd.melt(df, id_vars='Country')

# %%
df = df.rename(columns={'variable': 'Year', 'value': 'Emissions'})

# %%
df = df.set_index('Country')

# %%
print(df.shape)
df.head()
# Out:
# (2928, 2)
#                       Year  Emissions
# Country
# Afghanistan           2000   0.036574
# Angola                2000   0.988077
# Albania               2000   1.026213
# Andorra               2000   7.952286
# United Arab Emirates  2000  27.035159

# %%
# Export to csv
df.to_csv("emissions.csv")
